# %% [markdown]
# <a href="https://colab.research.google.com/github/Genius19245/Catching_Game/blob/main/imagerek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = "Shourya"

# %%
id(a)
# Out:
# 138162923225616

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
a = 10

# %%
x = 99
y = 200
z = y
y = x
x = z
print(x, y)
# Out:
# 200 99

# %%
print(id(x), id(y), id(z))
# Out:
# 138162923231696 138162923228464 138162923231696

# %%
x,y = y,x
print(x, y)
# Out:
# 99 200

# %%
x = x+y
y = x-y
x = x-y
print(x,y)
# Out:
# 200 99

# %%
name = 'I\'m Shourya.\nI live in Watford.\nMy age is 15.\n'
print(name)
# Out:
# I'm Shourya.
# I live in Watford.
# My age is 15.

# %%
num = 589457477959475
print(num)
# Out:
# 589457477959475

# %%
num = 589_457_477_959_475
print(num+1)
# Out:
# 589457477959476

# %%
print(0x12345)
# Out:
# 74565

# %%
print(type(a))
# Out:
# 10

# %% [markdown]
# if x is less than y, than x%y always equal to x.

# %%
x = 123
y= 4
print(x%y)
# Out:
# 3

# %%
import json

import pandas as pd

# %%
df = pd.DataFrame ({
    "Labels": [
        {
            "Name": "Face",
            "Confidence": 99.99967956542969,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Head"
                },
                {
                    "Name": "Person"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Person Description"
                }
            ]
        },
        {
            "Name": "Head",
            "Confidence": 99.99967956542969,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Person"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Person Description"
                }
            ]
        },
        {
            "Name": "Person",
            "Confidence": 99.99967956542969,
            "Instances": [
                {
                    "BoundingBox": {
                        "Width": 0.26490214467048645,
                        "Height": 0.3980313539505005,
                        "Left": 0.27385178208351135,
                        "Top": 0.6019686460494995
                    },
                    "Confidence": 99.87093353271484
                },
                {
                    "BoundingBox": {
                        "Width": 0.46310898661613464,
                        "Height": 0.30582183599472046,
                        "Left": 0.5267171263694763,
                        "Top": 0.5536362528800964
                    },
                    "Confidence": 98.12279510498047
                },
                {
                    "BoundingBox": {
                        "Width": 0.3775396943092346,
                        "Height": 0.8883315324783325,
                        "Left": 0.00011383993842173368,
                        "Top": 0.10988224297761917
                    },
                    "Confidence": 97.75315856933594
                },
                {
                    "BoundingBox": {
                        "Width": 0.47683730721473694,
                        "Height": 0.3607703447341919,
                        "Left": 0.4642648696899414,
                        "Top": 0.6392296552658081
                    },
                    "Confidence": 97.48665618896484
                },
                {
                    "BoundingBox": {
                        "Width": 0.24014998972415924,
                        "Height": 0.46516603231430054,
                        "Left": 0.7593194246292114,
                        "Top": 0.5348339676856995
                    },
                    "Confidence": 95.99500274658203
                },
                {
                    "BoundingBox": {
                        "Width": 0.17675186693668365,
                        "Height": 0.38283640146255493,
                        "Left": 0.4157043695449829,
                        "Top": 0.6167981028556824
                    },
                    "Confidence": 83.20997619628906
                },
                {
                    "BoundingBox": {
                        "Width": 0.10748759657144547,
                        "Height": 0.12454305589199066,
                        "Left": 0.6565766334533691,
                        "Top": 0.4543493390083313
                    },
                    "Confidence": 81.25630950927734
                }
            ],
            "Parents": [],
            "Aliases": [
                {
                    "Name": "Human"
                }
            ],
            "Categories": [
                {
                    "Name": "Person Description"
                }
            ]
        },
        {
            "Name": "Photography",
            "Confidence": 99.99967956542969,
            "Instances": [],
            "Parents": [],
            "Aliases": [
                {
                    "Name": "Photo"
                }
            ],
            "Categories": [
                {
                    "Name": "Hobbies and Interests"
                }
            ]
        },
        {
            "Name": "Portrait",
            "Confidence": 99.99967956542969,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Face"
                },
                {
                    "Name": "Head"
                },
                {
                    "Name": "Person"
                },
                {
                    "Name": "Photography"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Hobbies and Interests"
                }
            ]
        },
        {
            "Name": "Accessories",
            "Confidence": 99.99940490722656,
            "Instances": [],
            "Parents": [],
            "Aliases": [
                {
                    "Name": "Accessory"
                }
            ],
            "Categories": [
                {
                    "Name": "Apparel and Accessories"
                }
            ]
        },
        {
            "Name": "Sunglasses",
            "Confidence": 99.99940490722656,
            "Instances": [
                {
                    "BoundingBox": {
                        "Width": 0.13425412774085999,
                        "Height": 0.03018755279481411,
                        "Left": 0.5907730460166931,
                        "Top": 0.5978276133537292
                    },
                    "Confidence": 99.98641967773438
                },
                {
                    "BoundingBox": {
                        "Width": 0.11257544159889221,
                        "Height": 0.027170149609446526,
                        "Left": 0.8124645352363586,
                        "Top": 0.58896404504776
                    },
                    "Confidence": 99.85185241699219
                }
            ],
            "Parents": [
                {
                    "Name": "Accessories"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Apparel and Accessories"
                }
            ]
        },
        {
            "Name": "Clothing",
            "Confidence": 99.99935913085938,
            "Instances": [],
            "Parents": [],
            "Aliases": [
                {
                    "Name": "Apparel"
                }
            ],
            "Categories": [
                {
                    "Name": "Apparel and Accessories"
                }
            ]
        },
        {
            "Name": "T-Shirt",
            "Confidence": 99.99935913085938,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Clothing"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Apparel and Accessories"
                }
            ]
        },
        {
            "Name": "Glasses",
            "Confidence": 99.98696899414062,
            "Instances": [
                {
                    "BoundingBox": {
                        "Width": 0.1438141018152237,
                        "Height": 0.040486883372068405,
                        "Left": 0.5698734521865845,
                        "Top": 0.6937317848205566
                    },
                    "Confidence": 69.08891296386719
                }
            ],
            "Parents": [
                {
                    "Name": "Accessories"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Apparel and Accessories"
                }
            ]
        },
        {
            "Name": "People",
            "Confidence": 99.96687316894531,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Person"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Person Description"
                }
            ]
        },
        {
            "Name": "Baseball Cap",
            "Confidence": 99.88838195800781,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Cap"
                },
                {
                    "Name": "Clothing"
                },
                {
                    "Name": "Hat"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Apparel and Accessories"
                }
            ]
        },
        {
            "Name": "Cap",
            "Confidence": 99.88838195800781,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Clothing"
                },
                {
                    "Name": "Hat"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Apparel and Accessories"
                }
            ]
        },
        {
            "Name": "Hat",
            "Confidence": 99.88838195800781,
            "Instances": [
                {
                    "BoundingBox": {
                        "Width": 0.3861236274242401,
                        "Height": 0.24014103412628174,
                        "Left": 0,
                        "Top": 0.10504548996686935
                    },
                    "Confidence": 68.22320556640625
                },
                {
                    "BoundingBox": {
                        "Width": 0.19756753742694855,
                        "Height": 0.08084990084171295,
                        "Left": 0.5158917307853699,
                        "Top": 0.6373947858810425
                    },
                    "Confidence": 59.54602813720703
                }
            ],
            "Parents": [
                {
                    "Name": "Clothing"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Apparel and Accessories"
                }
            ]
        },
        {
            "Name": "Adult",
            "Confidence": 99.87093353271484,
            "Instances": [
                {
                    "BoundingBox": {
                        "Width": 0.26490214467048645,
                        "Height": 0.3980313539505005,
                        "Left": 0.27385178208351135,
                        "Top": 0.6019686460494995
                    },
                    "Confidence": 99.87093353271484
                },
                {
                    "BoundingBox": {
                        "Width": 0.46310898661613464,
                        "Height": 0.30582183599472046,
                        "Left": 0.5267171263694763,
                        "Top": 0.5536362528800964
                    },
                    "Confidence": 98.12279510498047
                },
                {
                    "BoundingBox": {
                        "Width": 0.3775396943092346,
                        "Height": 0.8883315324783325,
                        "Left": 0.00011383993842173368,
                        "Top": 0.10988224297761917
                    },
                    "Confidence": 97.75315856933594
                },
                {
                    "BoundingBox": {
                        "Width": 0.47683730721473694,
                        "Height": 0.3607703447341919,
                        "Left": 0.4642648696899414,
                        "Top": 0.6392296552658081
                    },
                    "Confidence": 97.48665618896484
                },
                {
                    "BoundingBox": {
                        "Width": 0.24014998972415924,
                        "Height": 0.46516603231430054,
                        "Left": 0.7593194246292114,
                        "Top": 0.5348339676856995
                    },
                    "Confidence": 95.99500274658203
                }
            ],
            "Parents": [
                {
                    "Name": "Person"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Person Description"
                }
            ]
        },
        {
            "Name": "Female",
            "Confidence": 99.87093353271484,
            "Instances": [
                {
                    "BoundingBox": {
                        "Width": 0

                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Buildings and Architecture"
                }
            ]
        },
        {
            "Name": "Urban",
            "Confidence": 90.67127990722656,
            "Instances": [],
            "Parents": [],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Colors and Visual Composition"
                }
            ]
        },
        {
            "Name": "Selfie",
            "Confidence": 87.4124755859375,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Face"
                },
                {
                    "Name": "Head"
                },
                {
                    "Name": "Person"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Colors and Visual Composition"
                }
            ]
        },
        {
            "Name": "Baby",
            "Confidence": 81.25630950927734,
            "Instances": [
                {
                    "BoundingBox": {
                        "Width": 0.10748759657144547,
                        "Height": 0.12454305589199066,
                        "Left": 0.6565766334533691,
                        "Top": 0.4543493390083313
                    },
                    "Confidence": 81.25630950927734
                }
            ],
            "Parents": [
                {
                    "Name": "Person"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Person Description"
                }
            ]
        },
        {
            "Name": "Photobombing",
            "Confidence": 80.73201751708984,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Person"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Actions"
                }
            ]
        },
        {
            "Name": "Castle",
            "Confidence": 78.77349853515625,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Architecture"
                },
                {
                    "Name": "Building"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Buildings and Architecture"
                }
            ]
        },
        {
            "Name": "Fortress",
            "Confidence": 78.77349853515625,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Architecture"
                },
                {
                    "Name": "Building"
                },
                {
                    "Name": "Castle"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Buildings and Architecture"
                }
            ]
        },
        {
            "Name": "Arch",
            "Confidence": 78.50035858154297,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Architecture"
                }
            ],
            "Aliases": [
                {
                    "Name": "Arched"
                }
            ],
            "Categories": [
                {
                    "Name": "Buildings and Architecture"
                }
            ]
        },
        {
            "Name": "Gothic Arch",
            "Confidence": 78.50035858154297,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Arch"
                },
                {
                    "Name": "Architecture"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Buildings and Architecture"
                }
            ]
        },
        {
            "Name": "VR Headset",
            "Confidence": 67.1548843383789,
            "Instances": [
                {
                    "BoundingBox": {
                        "Width": 0.27781999111175537,
                        "Height": 0.1758745014667511,
                        "Left": 0,
                        "Top": 0.16852684319019318
                    },
                    "Confidence": 67.1548843383789
                }
            ],
            "Parents": [],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Technology and Computing"
                }
            ]
        },
        {
            "Name": "Blouse",
            "Confidence": 57.50634765625,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Clothing"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Apparel and Accessories"
                }
            ]
        },
        {
            "Name": "Coat",
            "Confidence": 57.3707275390625,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Clothing"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Apparel and Accessories"
                }
            ]
        },
        {
            "Name": "Fun",
            "Confidence": 57.129581451416016,
            "Instances": [],
            "Parents": [],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Travel and Adventure"
                }
            ]
        },
        {
            "Name": "Tourist",
            "Confidence": 57.129581451416016,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Fun"
                },
                {
                    "Name": "Person"
                },
                {
                    "Name": "Vacation"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Person Description"
                }
            ]
        },
        {
            "Name": "Vacation",
            "Confidence": 57.129581451416016,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Fun"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Travel and Adventure"
                }
            ]
        },
        {
            "Name": "Shirt",
            "Confidence": 57.022674560546875,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Clothing"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Apparel and Accessories"
                }
            ]
        },
        {
            "Name": "Outdoors",
            "Confidence": 56.298004150390625,
            "Instances": [],
            "Parents": [],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Nature and Outdoors"
                }
            ]
        },
        {
            "Name": "Shelter",
            "Confidence": 56.298004150390625,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Architecture"
                },
                {
                    "Name": "Building"
                },
                {
                    "Name": "Outdoors"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Buildings and Architecture"
                }
            ]
        },
        {
            "Name": "Happy",
            "Confidence": 56.062103271484375,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Face"
                },
                {
                    "Name": "Head"
                },
                {
                    "Name": "Person"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Expressions and Emotions"
                }
            ]
        },
        {
            "Name": "Smile",
            "Confidence": 56.062103271484375,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Face"
                },
                {
                    "Name": "Happy"
                },
                {
                    "Name": "Head"
                },
                {
                    "Name": "Person"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Expressions and Emotions"
                }
            ]
        },
        {
            "Name": "Costume",
            "Confidence": 55.81841278076172,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Clothing"
                },
                {
                    "Name": "Person"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Apparel and Accessories"
                }
            ]
        },
        {
            "Name": "Pants",
            "Confidence": 55.75397491455078,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Clothing"
                }
            ],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Apparel and Accessories"
                }
            ]
        },
        {
            "Name": "Window",
            "Confidence": 55.08528518676758,
            "Instances": [],
            "Parents": [],
            "Aliases": [],
            "Categories": [
                {
                    "Name": "Home and Indoors"
                }
            ]
        },
        {
            "Name": "Alley",
            "Confidence": 55.04219055175781,
            "Instances": [],
            "Parents": [
                {
                    "Name": "City"
                },
                {
                    "Name": "Road"
                },
                {
                    "Name": "Street"
                },
                {
                    "Name": "Urban"
                }
            ],
            "Aliases": [
                {
                    "Name": "Alleyway"
                }
            ],
            "Categories": [
                {
                    "Name": "Buildings and Architecture"
                }
            ]
        }
    ],
    "LabelModelVersion": "3.0"
})

# %%
print(df['Labels'])
# Out:
# 0     {'Name': 'Face', 'Confidence': 99.999679565429...
# 1     {'Name': 'Head', 'Confidence': 99.999679565429...
# 2     {'Name': 'Person', 'Confidence': 99.9996795654...
# 3     {'Name': 'Photography', 'Confidence': 99.99967...
# 4     {'Name': 'Portrait', 'Confidence': 99.99967956...
# 5     {'Name': 'Accessories', 'Confidence': 99.99940...
# 6     {'Name': 'Sunglasses', 'Confidence': 99.999404...
# 7     {'Name': 'Clothing', 'Confidence': 99.99935913...
# 8     {'Name': 'T-Shirt', 'Confidence': 99.999359130...
# 9     {'Name': 'Glasses', 'Confidence': 99.986968994...
# 10    {'Name': 'People', 'Confidence': 99.9668731689...
# 11    {'Name': 'Baseball Cap', 'Confidence': 99.8883...
# 12    {'Name': 'Cap', 'Confidence': 99.8883819580078...
# 13    {'Name': 'Hat', 'Confidence': 99.8883819580078...
# 14    {'Name': 'Adult', 'Confidence': 99.87093353271...
# 15    {'Name': 'Female', 'Confidence': 99.8709335327...
# 16    {'Name': 'Woman', 'Confidence': 99.87093353271...
# ...

# %%
print(df)
# Out:
#                                                Labels LabelModelVersion
# 0   {'Name': 'Face', 'Confidence': 99.999679565429...               3.0
# 1   {'Name': 'Head', 'Confidence': 99.999679565429...               3.0
# 2   {'Name': 'Person', 'Confidence': 99.9996795654...               3.0
# 3   {'Name': 'Photography', 'Confidence': 99.99967...               3.0
# 4   {'Name': 'Portrait', 'Confidence': 99.99967956...               3.0
# 5   {'Name': 'Accessories', 'Confidence': 99.99940...               3.0
# 6   {'Name': 'Sunglasses', 'Confidence': 99.999404...               3.0
# 7   {'Name': 'Clothing', 'Confidence': 99.99935913...               3.0
# 8   {'Name': 'T-Shirt', 'Confidence': 99.999359130...               3.0
# 9   {'Name': 'Glasses', 'Confidence': 99.986968994...               3.0
# 10  {'Name': 'People', 'Confidence': 99.9668731689...               3.0
# 11  {'Name': 'Baseball Cap', 'Confidence': 99.8883...               3.0
# ...

# %%
def DataFramer(data):
  print(data.describe())
  print(data)

# %%
DataFramer(df)
# Out:
# Your data is $data and some description of it is $data.describe()
#                                                    Labels LabelModelVersion
# count                                                  49                49
# unique                                                 49                 1
# top     {'Name': 'Face', 'Confidence': 99.999679565429...               3.0
# freq                                                    1                49
#                                                Labels LabelModelVersion
# 0   {'Name': 'Face', 'Confidence': 99.999679565429...               3.0
# 1   {'Name': 'Head', 'Confidence': 99.999679565429...               3.0
# 2   {'Name': 'Person', 'Confidence': 99.9996795654...               3.0
# 3   {'Name': 'Photography', 'Confidence': 99.99967...               3.0
# 4   {'Name': 'Portrait', 'Confidence': 99.99967956...               3.0
# 5   {'Name': 'Accessories', 'Confidence': 99.99940...               3.0
# ...
